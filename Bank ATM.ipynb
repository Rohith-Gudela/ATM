# %%
import random
import time
print("Welcome to the Reserve Bank of India ATM")
print("Please insert your ATM Card")
time.sleep(2)
print("Don't remove until the process is completed")
time.sleep(2)
print('Type PIN as 1234 ')
balance=float(random.randint(1000,100000))
available_balance=balance
deposit=0
money=0
chances=3
while chances <=3:
    available_balance+=deposit-money
    pin=int(input("Enter your four digit pin number: "))
    if pin==1234:
        print("You have entered your pin correctly \n ")
        time.sleep(1)
        while True:
            
            print("\nPlease Press 1 -- Check Balance \n" )
            time.sleep(0.5)
            print("Please Press 2 -- Make a Withdrawl\n")
            time.sleep(0.5)
            print("Please Press 3 -- Deposit\n")
            time.sleep(0.5)
            print("Please Press 4 -- Mini Statement\n")
            time.sleep(0.5)
            print("Please Press 5 -- Exit\n")
            time.sleep(0.5)
            user_input=input("Enter your option: ")
            print("\n")

            time.sleep(2)
            if user_input=='1':
                print("Your current balance is 💲",available_balance)
                time.sleep(2)
                print("\n")
                print("Please Press 1 == Go back for Menu")
                print("Please Press 2 == Exit")
                choice=input("Enter your choice: ")
                time.sleep(3)
                print("\n")
                if choice=='2':
                    print("Please take your Card.")
                    time.sleep(2)
                    print("Thank You for Using this ATM. Visit Again 😀")
                    break
                    
            elif user_input=='2':
                money=int(input("Enter Withdrawl Money: "))
                if money >=50000:
                    print("\nThe daily withdrawl limit is 50000")
                elif money > available_balance:
                    print("\nThe money you have entered is not present in your current bank Account")
                elif money < 50000:
                    print("processing..........")
                    print("\n")
                    print("\n")
                    print("Please collect the cash")
                    time.sleep(1)
                    print("You have sucessfully withdrawl your money")
                    print("\n")
                    available_balance=available_balance-money
                    print("Do you want to know your current balance??")
                    answer=int(input("Enter Yes for 1 & No for 2: "))
                    print("\n")
                    if answer==1:
                        print("Your Current balance is 💲 ",available_balance)
                        time.sleep(1)
                        print("\n")
                        print("Please Press 1 == Go back for Menu")
                        print("Please Press 2 == Exit")
                        choice=input("Enter your choice: ")
                        time.sleep(3)
                        print("\n")
                        if choice=='2':
                            print("Please take your Card.")
                            time.sleep(2)
                            print("Thank You for Using this ATM. Visit Again 😀")
                            break  
                    else:
                        break 
                else:
                    print("\nDaily limit is 50,000, you have entered more than 50,000")
                    
            elif user_input=='3':
                deposit=int(input("\nPlease Enter the money to be deposited: "))
                if deposit >50000:
                    print("\nFor Deposit daily limit exceeded")
                    time.sleep(1)
                else:
                    available_balance+=deposit-money
                    print("Please enter the cash")
                    print("Still Validating.......")
                    time.sleep(5)
                    print("\n")
                    print("\n")
                    print("Amount is successfully deposited in your account\n")
                    print("Would you like to the check the balance???")
                    response=int(input("Enter Yes for 1 & No for 2: "))
                    print("\n")
                    if response==1:
                        print("Your Current balance is 💲 ",available_balance)
                        time.sleep(1)
                        print("\n")
                        print("Please Press 1 == Go back for Menu")
                        print("Please Press 2 == Exit")
                        response2=input("Enter your choice: ")
                        time.sleep(3)
                        print("\n")
                        if response2=='2':
                            print("Please take your Card.")
                            time.sleep(2)
                            print("Thank You for Using this ATM. Visit Again 😀")
                            break 
            elif user_input=='4':
                print("Please enter inbetween last 1-6 months of transations.\n")
                transactions=int(input("\nHow many months of the transactions do you need??- "))
                time.sleep(2)
                print("\n")
                if transactions in (1,2,3,4,5,6):
                    print("Please collect the last ",transactions," transactions receipt")
                    time.sleep(2)
                    print("\n")
                    print("Please Press 1 == Go back for Menu")
                    print("Please Press 2 == Exit")
                    response2=input("Enter your choice: ")
                    time.sleep(3)
                    print("\n")
                    if response2=='2':
                        print("Please take your Card.")
                        time.sleep(2)
                        print("Thank You for Using this ATM. Visit Again 😀")
                        break 
                else:
                    print("You have selected more than six months of transactions.")    
            elif user_input=='5':
                print("Please take your Card.")
                time.sleep(2)
                print("Thank You for Using this ATM. Visit Again 😀")
                break  
                
            else:
                print("You have entered wrong number")
        break    
        
    else:
        print("You have entered wrong pin number")
        chances -= 1
        if chances==0:
            print("You ATM card has blocked")
            break
# Out:
# Welcome to the Reserve Bank of India ATM
# Please insert your ATM Card
# Don't remove until the process is completed
# Type PIN as 1234
